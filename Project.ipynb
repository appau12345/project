# %% [markdown]
# ## Name : Akua Konadu Appau
# ## ID : 11119331
# ## Department : MTEN
# ---

# %% [markdown]
# #

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
dataset = pd.read_csv('red_wine.csv')

# %%
dataset.columns = dataset.columns.str.replace(" ","_")
dataset
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
dataset.tail(20)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1598 non-null   float64
#  1   volatile_acidity      1598 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free_sulfur_dioxide   1598 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
dataset_statistics = dataset.describe()
dataset_statistics
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# ##

# %% [markdown]
# ### Checking for missing values
# ---

# %%
dataset.isnull().sum()
# Out:
# fixed_acidity           1
# volatile_acidity        1
# citric_acid             0
# residual_sugar          0
# chlorides               4
# free_sulfur_dioxide     1
# total_sulfur_dioxide    0
# density                 1
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
max_fa = dataset_s.fixed_acidity.loc['max']
max_va = dataset_s.volatile_acidity.loc['max']
max_c = dataset_s.chlorides.loc['max']
max_fsd = dataset_s.free_sulfur_dioxide.loc['max']
max_d = dataset_s.density.loc['max']
max_q = dataset_s.quality.loc['max']

# %%
nDataset = dataset.copy()

# %%
nDataset.fixed_acidity = dataset.fixed_acidity.fillna(max_fa)
nDataset.volatile_acidity = dataset.volatile_acidity.fillna(max_va)
nDataset.chlorides = dataset.chlorides.fillna(max_c)
nDataset.free_sulfur_dioxide = dataset.free_sulfur_dioxide.fillna(max_fsd)
nDataset.density = dataset.density.fillna(max_d)
nDataset.quality = dataset.quality.fillna(max_q)

# %%
nDataset.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Checking for duplicated values
# ---

# %%
nDataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
nDataset =nDataset.drop_duplicates()

# %%
nDataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 1593    False
# 1594    False
# 1595    False
# 1597    False
# 1598    False
# Length: 1360, dtype: bool

# %%
nDataset_s =nDataset.describe()
nDataset_s
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1360.000000       1360.000000  1360.000000     1360.000000
# mean        8.315588          0.530217     0.272500        2.523235
# std         1.747937          0.185152     0.195562        1.351830
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1360.000000          1360.000000           1360.000000  1360.000000
# mean      0.089668            15.934559             46.843750     0.996715
# std       0.056902            10.553664             33.403084     0.001879
# ...

# %% [markdown]
# #
# ##

# %% [markdown]
# ### The dataset set(red_wine.csv) imported is a collection of dataset on the properties and components of multiple different kinds of red wine.

# %%
# %matplotlib inline

# %% [markdown]
# ## Histogram
# ---

# %%
plt.hist(nDataset.density, bins= np.arange(0.990,1.003,0.001) , rwidth= 0.7)

plt.title('Densities of Red Wines', fontdict= {'fontweight': 'bold'})
plt.xlabel('Density')
plt.ylabel('Red wine')

plt.show()

# %% [markdown]
# ### From the histogram, most red wines possess densities within the range of  0.996 - 0.997 .
# ### At the same time few red wines possess densities within the range of 0.990 - 0.991 .

# %% [markdown]
# ##
# ## Scatter graph
# ---

# %%
plt.title('Fixed acidity over pH', fontdict= {'fontweight': 'bold'})
plt.scatter(x='pH',y='fixed_acidity',data = nDataset, c= 'r')
plt.xlabel('pH')
plt.ylabel('Fixed acidity')

plt.legend()

# %% [markdown]
# ### From the graph it can be sayd that those with a lower pH had a higher fixed acidity and those with higher pH had a lower fixed acidity.
# ### Therefore as the pH of a red wine increases, it's fixed acidity decreases.

# %% [markdown]
# #

# %% [markdown]
# ## Number of red wines with a specific quality.
# ---

# %%
nQuality = pd.DataFrame(nDataset.quality.value_counts())
nQuality
# Out:
#          count
# quality
# 5.0        578
# 6.0        534
# 7.0        167
# 4.0         53
# 8.0         18
# 3.0         10

# %% [markdown]
# #

# %% [markdown]
# ##

# %% [markdown]
# #
